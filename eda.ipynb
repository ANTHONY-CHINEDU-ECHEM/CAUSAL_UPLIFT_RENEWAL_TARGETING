# %% [markdown]
# # EDA — Causal Uplift Renewal Dataset

# %%
import pandas as pd
df = pd.read_csv('../data/renewals.csv')
df.groupby('treated_discount_offered')['renewed'].mean()

# %% [markdown]
# ## True heterogeneous effect distribution (ground truth, synthetic only)

# %%
df['_true_causal_effect_logodds'].hist(bins=40)
